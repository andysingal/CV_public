# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.3/664.3 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/v2/Source
# Out:
# /content/drive/MyDrive/v2/Source

# %%
# !ls
# Out:
#  data.yaml				      README.dataset.txt    test    valid
# 'histogram 8x8.v1-histogram-8x8.yolov8.zip'   README.roboflow.txt   train   yolov8n.pt

# %%
# !unzip "histogram 8x8.v1-histogram-8x8.yolov8.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/labels/1811_jpg.rf.6ff2dee0a5ad067b9875e8553f95e57c.txt
#  extracting: train/labels/1811_jpg.rf.af035bad4fe9a604358cf3a6102969f9.txt
#  extracting: train/labels/1812_jpg.rf.4acf46204da3053704a9c7b38f7988b6.txt
#  extracting: train/labels/1812_jpg.rf.9696f9b0e4b218707f759cba472b3364.txt
#  extracting: train/labels/1813_jpg.rf.52c8bf1e3c1084c18736677aaa12f073.txt
#  extracting: train/labels/1813_jpg.rf.b8e9ff8f6500ba562d1a8f1882ee558b.txt
#  extracting: train/labels/1814_jpg.rf.f356e5ebc6bab0363ba3536bad3b164e.txt
#  extracting: train/labels/1815_jpg.rf.cb5b6572768284d21cfea5400171c6e3.txt
#  extracting: train/labels/1816_jpg.rf.ab9b197ab5e08f5bc21a7d7a32550363.txt
#  extracting: train/labels/1817_jpg.rf.4f73403be3c8452c4b86d094d779eb5c.txt
#  extracting: train/labels/1817_jpg.rf.980178af36bd99ff2e0cdae20822429d.txt
#  extracting: train/labels/1819_jpg.rf.57c436c0a6ffa303de372a382bcd4db8.txt
# ...

# %%
#Training YOLOv8 on a custom dataset
# !yolo task = detect mode = train model = yolov8n.pt data = /content/drive/MyDrive/v2/Source/data.yaml epochs = 500 imgsz= 512 project = /content/drive/MyDrive/v2/Results
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 110MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import matplotlib.pyplot as plt
import cv2

original_image = cv2.imread('/content/drive/MyDrive/v2/Source/test/images/820_jpg.rf.30a6506f7c13592aa30bc5f40f593e0a.jpg')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/v2/Results/train/weights/best.pt source = /content/drive/MyDrive/v2/Source/test/images/820_jpg.rf.30a6506f7c13592aa30bc5f40f593e0a.jpg  project = /content/drive/MyDrive/v2/Results/ImageResults
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/v2/Source/test/images/820_jpg.rf.30a6506f7c13592aa30bc5f40f593e0a.jpg: 512x512 1 0, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2164.8ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /content/drive/MyDrive/v2/Results/ImageResults/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = cv2.imread('/content/drive/MyDrive/v2/Results/ImageResults/predict6/820_jpg.rf.30a6506f7c13592aa30bc5f40f593e0a.jpg')
plt.imshow(cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB))

# %%
original_image = cv2.imread('/content/drive/MyDrive/v2/Source/test/images/14_jpg.rf.09e2d3712482dbbb6429dbee84d9e26a.jpg')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/v2/Results/train/weights/best.pt source = /content/drive/MyDrive/v2/Source/test/images/14_jpg.rf.09e2d3712482dbbb6429dbee84d9e26a.jpg  project = /content/drive/MyDrive/v2/Results/ImageResults
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/v2/Source/test/images/14_jpg.rf.09e2d3712482dbbb6429dbee84d9e26a.jpg: 512x512 1 1, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 580.1ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to /content/drive/MyDrive/v2/Results/ImageResults/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = cv2.imread('/content/drive/MyDrive/v2/Results/ImageResults/predict2/14_jpg.rf.09e2d3712482dbbb6429dbee84d9e26a.jpg')
plt.imshow(cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB))

# %%
original_image = cv2.imread('/content/drive/MyDrive/v2/Source/test/images/deneme.jpg')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/v2/Results/train/weights/best.pt source = /content/drive/MyDrive/v2/Source/test/images/deneme.jpg  project = /content/drive/MyDrive/v2/Results/ImageResults
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/v2/Source/test/images/deneme.jpg: 288x512 1 1, 103.3ms
# Speed: 8.5ms preprocess, 103.3ms inference, 536.6ms postprocess per image at shape (1, 3, 288, 512)
# Results saved to /content/drive/MyDrive/v2/Results/ImageResults/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
predicted_image = cv2.imread('/content/drive/MyDrive/v2/Results/ImageResults/predict3/deneme.jpg')
plt.imshow(cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB))

# %%
# prompt: detect all the photos /content/drive/MyDrive/v2/Source/test/images/ in that folder and save the results /content/drive/MyDrive/v2/Results/TestResults with my yolov8 model

# !yolo task = detect mode = predict model = /content/drive/MyDrive/v2/Results/train/weights/best.pt source = /content/drive/MyDrive/v2/Source/test/images/  project = /content/drive/MyDrive/v2/Results/TestResults
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/587 /content/drive/MyDrive/v2/Source/test/images/1000_jpg.rf.fea4f9f2785885ea4a296b637e59317b.jpg: 512x512 1 1, 6.6ms
# image 2/587 /content/drive/MyDrive/v2/Source/test/images/1002_jpg.rf.a71c2e2c6934df6373c490243e9c11a5.jpg: 512x512 1 1, 8.1ms
# image 3/587 /content/drive/MyDrive/v2/Source/test/images/1003_jpg.rf.6c87f76e358eb13f94f058e752dc53b6.jpg: 512x512 1 1, 7.1ms
# image 4/587 /content/drive/MyDrive/v2/Source/test/images/1010_jpg.rf.fb0d646e214af07c16e57acca996bcfc.jpg: 512x512 1 1, 6.7ms
# image 5/587 /content/drive/MyDrive/v2/Source/test/images/1014_jpg.rf.73dab7203b43458450a599913c7aad30.jpg: 512x512 1 1, 6.7ms
# image 6/587 /content/drive/MyDrive/v2/Source/test/images/1019_jpg.rf.ae4ac2d181064cf552af52eb22feb788.jpg: 512x512 1 1, 38.7ms
# ...

# %%
model = YOLO('/content/drive/MyDrive/v2/Results/train/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/v2/Source/valid/labels.cache... 1174 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1174/1174 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 74/74 [00:59<00:00,  1.25it/s]
#                    all       1174       1175      0.939      0.916      0.955      0.648
#                      0       1174        577       0.92       0.86      0.932      0.601
#                      1       1174        598      0.958      0.973      0.979      0.696
# Speed: 0.3ms preprocess, 3.3ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/val2
# array([     0.6006,     0.69598])
