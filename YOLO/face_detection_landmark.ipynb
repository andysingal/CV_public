# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ## Predict

# %%
# clone repo
# !git clone https://github.com/akanametov/yolov8-face

# go to code folder
# !cd yolov8-face
# Out:
# Cloning into 'yolov8-face'...
# remote: Enumerating objects: 3094, done.
# remote: Total 3094 (delta 0), reused 0 (delta 0), pack-reused 3094
# Receiving objects: 100% (3094/3094), 27.03 MiB | 27.65 MiB/s, done.
# Resolving deltas: 100% (2067/2067), done.

# %%
# !wget --quiet --show-progress https://github.com/Run-Pod/runpodctl/releases/download/v1.10.0/runpodctl-linux-amd -O runpodctl && chmod +x runpodctl && sudo cp runpodctl /usr/bin/runpodctl
# Out:
# runpodctl           100%[===================>]  11.81M  --.-KB/s    in 0.1s

# %%
# !runpodctl version
# Out:
# runpodctl v1.10.0

# %%
# !runpodctl receive 8813-velvet-global-sparta-1
# Out:
# Receiving 'yolov8n-face.pt' (6.0 MB)
#
# Receiving (<-103.40.201.69:49920)
# yolov8n-face.pt 100% |████████████████████| (6.0/6.0 MB, 2.022 MB/s)

# %%
# !yolo task=detect mode=predict model=yolov8n-face.pt conf=0.25 imgsz=1280 line_thickness=1 max_det=1000 source='https://ultralytics.com/images/zidane.jpg'
# Out:
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'line_width' instead.
# WARNING ⚠️ yolov8n-face.pt appears to require 'omegaconf', which is not in ultralytics requirements.
# AutoInstall will run now for 'omegaconf' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['omegaconf'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
from IPython.display import display, Image


Image(filename='/content/runs/detect/predict2/zidane.jpg', width=600)

# %% [markdown]
# Resource:
# - https://pypi.org/project/kadita/
# - https://medium.com/@6438232221/automatic-selfie-taker-using-smile-detection-fb7e9c101204
# - https://blog.csdn.net/walchina2017/article/details/130460915
